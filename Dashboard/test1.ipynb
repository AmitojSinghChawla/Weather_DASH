# %%
from Dashboard.schema_creation import cursor
from db import get_connected

# %%
conn = get_connected()
cursor = conn.cursor()

# %%
import pandas as pd

# %%
conn.rollback()

# %%
cursor.execute(""" SELECT * FROM locations;""")
cities = cursor.fetchall()

# %%
cities
# Out:
# [(6, 'Delhi', 'Delhi', 'India', Decimal('28.61390'), Decimal('77.20900')),
#  (7,
#   'Mumbai',
#   'Maharashtra',
#   'India',
#   Decimal('19.07600'),
#   Decimal('72.87770')),
#  (8,
#   'Bangalore',
#   'Karnataka',
#   'India',
#   Decimal('12.97160'),
#   Decimal('77.59460')),
#  (9,
#   'Kolkata',
#   'West Bengal',
#   'India',
#   Decimal('22.57260'),
#   Decimal('88.36390')),
#  (10,
#   'Chennai',
#   'Tamil Nadu',
#   'India',
#   Decimal('13.08270'),
#   Decimal('80.27070'))]

# %%
for city in cities:
    location_id = city[0]
    print(location_id)
# Out:
# 6
# 7
# 8
# 9
# 10
