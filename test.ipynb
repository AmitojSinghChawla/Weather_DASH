# %%
import requests
import os
from dotenv import load_dotenv
load_dotenv()

API_KEY = os.getenv("WEATHER_API_KEY")

# — Weather API —
lat, lon = 28.6139, 77.2090  # Delhi

weather_url = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API_KEY}&units=metric"
w = requests.get(weather_url).json()

# — Air Pollution API —
aqi_url = f"https://api.openweathermap.org/data/2.5/air_pollution?lat={lat}&lon={lon}&appid={API_KEY}"
a = requests.get(aqi_url).json()

# %%
w
# Out:
# {'coord': {'lon': 77.21, 'lat': 28.61},
#  'weather': [{'id': 500,
#    'main': 'Rain',
#    'description': 'light rain',
#    'icon': '10d'}],
#  'base': 'stations',
#  'main': {'temp': 33.8,
#   'feels_like': 39.69,
#   'temp_min': 33.8,
#   'temp_max': 33.8,
#   'pressure': 996,
#   'humidity': 55,
#   'sea_level': 996,
#   'grnd_level': 971},
#  'visibility': 10000,
#  'wind': {'speed': 3.23, 'deg': 141, 'gust': 2.9},
#  'rain': {'1h': 0.12},
#  'clouds': {'all': 100},
#  'dt': 1785244808,
#  'sys': {'country': 'IN', 'sunrise': 1785197402, 'sunset': 1785246303},
#  'timezone': 19800,
#  'id': 1260877,
#  'name': 'Parliament House, Delhi',
#  'cod': 200}

# %%
a
# Out:
# {'coord': {'lon': 77.21, 'lat': 28.61},
#  'list': [{'main': {'aqi': 2},
#    'components': {'co': 314.77,
#     'no': 0.18,
#     'no2': 6.86,
#     'o3': 94.76,
#     'so2': 1.19,
#     'pm2_5': 23.65,
#     'pm10': 27.65,
#     'nh3': 6.65},
#    'dt': 1785244808}]}
